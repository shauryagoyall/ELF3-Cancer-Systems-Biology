# %%
import pandas as pd
import numpy as np


replicates = ["r1","r2","r3"]
replicates = ["r3"]
stability_states = [1,2,3,4]
num_of_nodes = 6
genes = ["SLUG", "MIR", "ZEB",  "ERA66", "ERA36","ELF3"]
topo ="elf3"

for replicate in replicates:
    gene_networks =["elf3"]
    for network in gene_networks:

            for stability_state in stability_states:

                file_name = "./"+network+"/"+replicate+"/"+topo+"_solution_"+str(stability_state)+".dat"

                if stability_state == 1:

                    df1 = pd.read_csv(file_name, sep="\t", header = None)
                    df1 = df1.drop(columns = [0,1])

                    #print(df1)

                if stability_state == 2:

                    df2 = pd.read_csv(file_name, sep="\t", header = None)
                    df2 = df2.drop(columns = [0,1])

                    #print(df2)

                if stability_state == 3:

                    df3 = pd.read_csv(file_name, sep="\t", header = None)
                    df3 = df3.drop(columns = [0,1])

                    #print(df3)
                if stability_state == 4:

                    df7 = pd.read_csv(file_name, sep="\t", header = None)
                    df7 = df7.drop(columns = [0,1])

            #changing column index of latter half of bi stable data
            df4 = df2[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
            df4.set_axis(  range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of middle 1/3 of tri stable data
            df5 = df3[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
            df5.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of latter 1/3 of tri stable data
            df6 = df3[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
            df6.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of 2/4th of quad stable data
            df8 = df7[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
            df8.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of 3/4thof tri stable data
            df9 = df7[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
            df9.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of 4/4thof tri stable data
            df10 = df7[ range( ((num_of_nodes*3)+2), ((num_of_nodes*4)+2) ) ].copy(deep = True)
            df10.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)


            #concatenate all the dataframes one below the other
            df_new = pd.concat([ df1, df2[range(2,num_of_nodes+2)], df4, df3[range(2,num_of_nodes+2)], df5, df6, df7[range(2,num_of_nodes+2)], df8, df9, df10  ], ignore_index=True)

            #print("done")

            #print(df_new)
            i=0
            means = {}
            std_devs ={}
            for asa in range(2,num_of_nodes+2):
                node = df_new[asa]
                mean1 = np.mean(node)
                std_dev1 = np.std(node)
                means[asa]=mean1
                std_devs[asa]=std_dev1
                i+=1

    print(means)
    print(std_devs)

    import pandas as pd

    gene_networks =["elf3_oede"]
    oede=["_OE","_DE"]
    fold_node=["_3","_4","_6"]

    for network in gene_networks:

            for change in oede:
                  for fold in fold_node:
                    for stability_state in stability_states:

                        file_name = "./"+network+"/"+replicate+"/"+topo+change+fold+"_solution_"+str(stability_state)+".dat"

                        if stability_state == 1:

                            df1 = pd.read_csv(file_name, sep="\t", header = None)
                            df1 = df1.drop(columns = [0,1])

                            #print(df1)

                        if stability_state == 2:

                            df2 = pd.read_csv(file_name, sep="\t", header = None)
                            df2 = df2.drop(columns = [0,1])

                            #print(df2)

                        if stability_state == 3:

                            df3 = pd.read_csv(file_name, sep="\t", header = None)
                            df3 = df3.drop(columns = [0,1])

                            #print(df3)
                        if stability_state == 4:

                            df7 = pd.read_csv(file_name, sep="\t", header = None)
                            df7 = df7.drop(columns = [0,1])

                    #changing column index of latter half of bi stable data
                    df4 = df2[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
                    df4.set_axis(  range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of middle 1/3 of tri stable data
                    df5 = df3[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
                    df5.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of latter 1/3 of tri stable data
                    df6 = df3[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
                    df6.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of 2/4th of quad stable data
                    df8 = df7[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
                    df8.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of 3/4thof tri stable data
                    df9 = df7[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
                    df9.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of 4/4thof tri stable data
                    df10 = df7[ range( ((num_of_nodes*3)+2), ((num_of_nodes*4)+2) ) ].copy(deep = True)
                    df10.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)


                    #concatenate all the dataframes one below the other
                    df_oede = pd.concat([ df1, df2[range(2,num_of_nodes+2)], df4, df3[range(2,num_of_nodes+2)], df5, df6, df7[range(2,num_of_nodes+2)], df8, df9, df10  ], ignore_index=True)
                    df_z = pd.DataFrame()
                    i=0
                    for asa in range(2,num_of_nodes+2):
                        node = np.array(df_oede[asa])
                        z_value = ( (node - means[asa]) / std_devs[asa] )
                        df_z.insert(i, asa, z_value)
                        i+=1
                    save_name = "./"+network+"/"+replicate+"/"+"elf3"+change+fold+".xlsx"
                    df_z.to_excel(save_name , header = genes, index = False)
                    print("done   "+ topo+change+fold+".xlsx")
    print("done")
# Out:
# {2: -1.2753279606974635, 3: 2.067263834918157, 4: -2.5543751196960014, 5: -2.6460941093316834, 6: 4.182493503634922, 7: -0.8881513526525316}
# {2: 7.194114513916354, 3: 5.193442341440089, 4: 9.469527175139117, 5: 7.502554452585974, 6: 3.0274383782255803, 7: 4.902528757410856}
# done   elf3_OE_3.xlsx
# done   elf3_OE_4.xlsx
# done   elf3_OE_6.xlsx
# done   elf3_DE_3.xlsx
# done   elf3_DE_4.xlsx
# done   elf3_DE_6.xlsx
# done

# %%
import pandas as pd
import numpy as np


replicates = ["r1","r2","r3"]
stability_states = [1,2,3,4]
num_of_nodes = 6
genes = ["SLUG", "MIR", "ZEB",  "ERA66", "ERA36","ELF3"]
topo ="elf3"

for replicate in replicates:
    gene_networks =["elf3"]
    for network in gene_networks:

            for stability_state in stability_states:

                file_name = "./"+network+"/"+replicate+"/"+"elf3"+"_solution_"+str(stability_state)+".dat"

                if stability_state == 1:

                    df1 = pd.read_csv(file_name, sep="\t", header = None)
                    df1 = df1.drop(columns = [0,1])

                    #print(df1)

                if stability_state == 2:

                    df2 = pd.read_csv(file_name, sep="\t", header = None)
                    df2 = df2.drop(columns = [0,1])

                    #print(df2)

                if stability_state == 3:

                    df3 = pd.read_csv(file_name, sep="\t", header = None)
                    df3 = df3.drop(columns = [0,1])

                    #print(df3)
                if stability_state == 4:

                    df7 = pd.read_csv(file_name, sep="\t", header = None)
                    df7 = df7.drop(columns = [0,1])

            #changing column index of latter half of bi stable data
            df4 = df2[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
            df4.set_axis(  range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of middle 1/3 of tri stable data
            df5 = df3[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
            df5.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of latter 1/3 of tri stable data
            df6 = df3[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
            df6.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of 2/4th of quad stable data
            df8 = df7[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
            df8.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of 3/4thof tri stable data
            df9 = df7[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
            df9.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

            #changing column index of 4/4thof tri stable data
            df10 = df7[ range( ((num_of_nodes*3)+2), ((num_of_nodes*4)+2) ) ].copy(deep = True)
            df10.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)


            #concatenate all the dataframes one below the other
            df_new = pd.concat([ df1, df2[range(2,num_of_nodes+2)], df4, df3[range(2,num_of_nodes+2)], df5, df6, df7[range(2,num_of_nodes+2)], df8, df9, df10  ], ignore_index=True)

            #print("done")

            #print(df_new)
            i=0
            means = {}
            std_devs ={}
            for asa in range(2,num_of_nodes+2):
                node = df_new[asa]
                mean1 = np.mean(node)
                std_dev1 = np.std(node)
                means[asa]=mean1
                std_devs[asa]=std_dev1
                i+=1

    print(means)
    print(std_devs)

    import pandas as pd

    gene_networks =["both"]

    for network in gene_networks:
                    for stability_state in stability_states:

                        file_name = "./"+"both_100elf3"+"/"+replicate+"/"+"both"+"_solution_"+str(stability_state)+".dat"

                        if stability_state == 1:

                            df1 = pd.read_csv(file_name, sep="\t", header = None)
                            df1 = df1.drop(columns = [0,1])

                            #print(df1)

                        if stability_state == 2:

                            df2 = pd.read_csv(file_name, sep="\t", header = None)
                            df2 = df2.drop(columns = [0,1])

                            #print(df2)

                        if stability_state == 3:

                            df3 = pd.read_csv(file_name, sep="\t", header = None)
                            df3 = df3.drop(columns = [0,1])

                            #print(df3)
                        if stability_state == 4:

                            df7 = pd.read_csv(file_name, sep="\t", header = None)
                            df7 = df7.drop(columns = [0,1])

                    #changing column index of latter half of bi stable data
                    df4 = df2[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
                    df4.set_axis(  range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of middle 1/3 of tri stable data
                    df5 = df3[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
                    df5.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of latter 1/3 of tri stable data
                    df6 = df3[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
                    df6.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of 2/4th of quad stable data
                    df8 = df7[ range( num_of_nodes+2, ((num_of_nodes*2)+2) ) ].copy(deep = True)
                    df8.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of 3/4thof tri stable data
                    df9 = df7[ range( ((num_of_nodes*2)+2), ((num_of_nodes*3)+2) ) ].copy(deep = True)
                    df9.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)

                    #changing column index of 4/4thof tri stable data
                    df10 = df7[ range( ((num_of_nodes*3)+2), ((num_of_nodes*4)+2) ) ].copy(deep = True)
                    df10.set_axis( range(2,num_of_nodes+2) , axis=1, inplace=True)


                    #concatenate all the dataframes one below the other
                    df_oede = pd.concat([ df1, df2[range(2,num_of_nodes+2)], df4, df3[range(2,num_of_nodes+2)], df5, df6, df7[range(2,num_of_nodes+2)], df8, df9, df10  ], ignore_index=True)
                    df_z = pd.DataFrame()
                    i=0
                    for asa in range(2,num_of_nodes+2):
                        node = np.array(df_oede[asa])
                        z_value = ( (node - means[asa]) / std_devs[asa] )
                        df_z.insert(i, asa, z_value)
                        i+=1
                    save_name = "./"+"both_100elf3"+"/"+replicate+"/"+"both"+".xlsx"
                    df_z.to_excel(save_name , header = genes, index = False)
                    print("done   "+ "both"+".xlsx")
    print("done")
# Out:
# {2: -1.2444148324128834, 3: 2.0409593900950167, 4: -2.52379781395236, 5: -2.65123937798735, 6: 4.180525451671271, 7: -0.9075238925222109}
# {2: 7.183030172953445, 3: 5.205116087092, 4: 9.459520131997909, 5: 7.501162224079161, 6: 3.02667663454145, 7: 4.90414365850458}
# done   both.xlsx
# done
# {2: -1.2515770460983011, 3: 2.049678694743436, 4: -2.516855852331314, 5: -2.645613131465178, 6: 4.176878637691463, 7: -0.907906939063349}
# {2: 7.19060476451228, 3: 5.202574570638835, 4: 9.45909148442643, 5: 7.501706533471303, 6: 3.0317078038554905, 7: 4.903293637044322}
# done   both.xlsx
# done
# {2: -1.2753279606974635, 3: 2.067263834918157, 4: -2.5543751196960014, 5: -2.6460941093316834, 6: 4.182493503634922, 7: -0.8881513526525316}
# {2: 7.194114513916354, 3: 5.193442341440089, 4: 9.469527175139117, 5: 7.502554452585974, 6: 3.0274383782255803, 7: 4.902528757410856}
# done   both.xlsx
# done
